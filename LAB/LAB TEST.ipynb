# %% [markdown]
# # SECTION A — CODE CORRECTION (40 Marks)

# %% [markdown]
# Question 1

# %%
def top_k(items, k):
    items.sort(items,key=lambda x: x[1], reverse=True)
    return items[:k]
items = [("A", 90), ("B", 95), ("C", 95), ("D", 85)]
k = 2
top_k(items,k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 items = [("A", 90), ("B", 95), ("C", 95), ("D", 85)]
#       5 k = 2
# ----> 6 top_k(items,k)
#
# Cell In[23], line 2, in top_k(items, k)
#       1 def top_k(items, k):
# ----> 2     items.sort(items,key=lambda x: x[1], reverse=True)
#       3     return items[:k]
#
# TypeError: sort() takes at most 2 arguments (3 given)

# %% [markdown]
# question 2

# %%
pairs = [("sports","win"), ("sports","win"), ("tech","ai")]

def count_by_category(pairs):
    for cat,word in

# %% [markdown]
# Question 3

# %%
def missing_number(nums):
    n = len(nums)
    total = n * (n + 1) / 2
    return int(total - sum(nums))

missing_number([1,0,3,2,5])
# Out:
# 4

# %% [markdown]
# Quetion 4

# %% [markdown]
# # SECTION B

# %% [markdown]
# Question 5

# %%
num=[1,2,3,4,5,6]
l2=[]
l=[]
for i in range(len(num)):
    l.append(num[i])
    sum=0
    for j in l:
        sum+=j
    avg=sum/len(l)
    l2.append(avg)
print(l2)
# Out:
# [1.0, 1.5, 2.0, 2.5, 3.0, 3.5]

# %% [markdown]
# Question 7

# %%
x="3a2b1c"

l=list(x)
for i in l:
