# %%
a=52485
b=str(a)
print(b)
for i in b:
    print(int(i))

# %% [markdown]
# # Printing the individual number
# - first convert the number into string
# - the traverse the stirng
# - and then printing the each char of string by type scripting it to int

# %%
a =121
b =a      
c =0
while a!=0:
    x = a % 10
    a = a//10
    c = (c*10)+x

if c == b:
    print("Palindrome")
else:
    print("Not Palindrome")

# %% [markdown]
# # Palindrome number
# - b is the variable in which orignal value of a is being stored to further match the value
# - c is the variable in which we will be calculating the palindrome number to check
# - while loop continues until a is greater than 0
# - and inside while loop we are firstly taking the remainder using the mod operator
# - in second step we are updating the value of a by removing the last digit
# - in var c we are saving the calue firstly by multiplying the cby 10 and adding the remainder to it

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
a =8208
b =a
arm =0
n =len(str(a))

while b>0:
    x =b%10
    arm +=x ** n
    b =b//10

if arm == a:
    print("Armstrong number")
else:
    print("Not Armstrong number")

# %% [markdown]
# # Armstrong number

# %% [markdown]
# - b is a variable in which the orignal number is being stored
# - in n the len of the variable a is store by explicitly converting it to string so that it can use the built in function len to check its length
# - while loop  runs untill the b is greater than 0
# - x stores the temainder value
# - arm stores the variable in which we are performing the calculation
#     - armstrong number is the one whose sum of digit power to the len of variable is equal to the orignal number
# - b then updates its value by removing the last digit from itself
# - then the condition is checked usinf if else if condition is true i.e, if the arm is eaual to tthe orignal number a then its a armstrong number
# - otherwise its not an armstrong number

# %%
print(type(round(3.256)))

# %% [markdown]
# ANY VALUE OTHER THAN 0 IS TRUE USING IF ELSE

# %% [markdown]
# # Q  expalain i simple psedocode how upper function is not a functon/ method  of the str class
# native to the class obj
# str.

# %% [markdown]
# # FOR LOOP
# SYNTAX >> for item in iterable

# %%
if ("abc"):
    print("OK")
# Out:
# OK

# %% [markdown]
# # LOOP
# for usages
# - enumerate
# - zip

# %% [markdown]
# intersection

# %%
x=5
match x:
    case 1:
        print("1")
    case 2:
        print("1")
    case 3:
        print("3")
    case 4:
        print("1")
    case 5:
        print("5")
# Out:
# 5

# %%
indexo
